# %%
# For analysis and cleaning
import pandas as pd
import numpy as np
# for visaluatztion
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/sentimentdataset.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
df.shape
# Out:
# (732, 15)

# %%
if 'Unnamed: 0.1' in df.columns:
    df.drop(columns='Unnamed: 0.1',inplace=True)
else:
    print("Column 'Unnamed: 0.1' not found in DataFrame.")

df.rename(columns={'Unnamed: 0':'id'},inplace=True)
df.head()
# Out:
#    id                                               Text    Sentiment  \
# 0   0   Enjoying a beautiful day at the park!        ...   Positive
# 1   1   Traffic was terrible this morning.           ...   Negative
# 2   2   Just finished an amazing workout! 💪          ...   Positive
# 3   3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         732 non-null    int64
#  1   Text       732 non-null    object
#  2   Sentiment  732 non-null    object
#  3   Timestamp  732 non-null    object
#  4   User       732 non-null    object
#  5   Platform   732 non-null    object
#  6   Hashtags   732 non-null    object
#  7   Retweets   732 non-null    float64
#  8   Likes      732 non-null    float64
#  9   Country    732 non-null    object
#  10  Year       732 non-null    int64
#  11  Month      732 non-null    int64
#  12  Day        732 non-null    int64
#  13  Hour       732 non-null    int64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 80.2+ KB

# %%
df['Platform'].value_counts()
# Out:
# Platform
# Instagram     258
# Facebook      231
# Twitter       128
# Twitter       115
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id           0
# Text         0
# Sentiment    0
# Timestamp    0
# User         0
# Platform     0
# Hashtags     0
# Retweets     0
# Likes        0
# Country      0
# Year         0
# Month        0
# Day          0
# Hour         0
# dtype: int64

# %%
df.describe()
# Out:
#                id    Retweets       Likes         Year       Month  \
# count  732.000000  732.000000  732.000000   732.000000  732.000000
# mean   369.740437   21.508197   42.901639  2020.471311    6.122951
# std    212.428936    7.061286   14.089848     2.802285    3.411763
# min      0.000000    5.000000   10.000000  2010.000000    1.000000
# 25%    185.750000   17.750000   34.750000  2019.000000    3.000000
# 50%    370.500000   22.000000   43.000000  2021.000000    6.000000
# 75%    553.250000   25.000000   50.000000  2023.000000    9.000000
# max    736.000000   40.000000   80.000000  2023.000000   12.000000
#
#               Day        Hour
# count  732.000000  732.000000
# mean    15.497268   15.521858
# std      8.474553    4.113414
# min      1.000000    0.000000
# 25%      9.000000   13.000000
# 50%     15.000000   16.000000
# 75%     22.000000   19.000000
# max     31.000000   23.000000

# %%
import pandas as pd

# Assuming df is your DataFrame
selected_countries = df[df['Country'].isin(['India', 'USA', 'Canada'])]

# %%
# For analysis and cleaning
import pandas as pd
import numpy as np
# for visaluatztion
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split


# Now 'df' is defined and can be used
x = df['Text']
y = df['Sentiment']
# Corrected the variable names in train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# Initialize the model (MultinomialNB needs to be initialized before fitting)
model = MultinomialNB()
# You also need to vectorize your text data before training the model
vectorizer = CountVectorizer()
x_train_vec = vectorizer.fit_transform(x_train)
x_test_vec = vectorizer.transform(x_test)
model.fit(x_train_vec, y_train)
y_pred = model.predict(x_test_vec)
print(y_pred)
# Out:
# [' Excitement ' ' Positive  ' ' Excitement ' ' Excitement ' ' Joy '
#  ' Joy ' ' Positive  ' ' Positive  ' ' Excitement ' ' Joy ' ' Excitement '
#  ' Excitement ' ' Positive  ' ' Excitement ' ' Acceptance      ' ' Sad '
#  ' Excitement ' ' Joy ' ' Joy ' ' Joy ' ' Joy ' ' Excitement ' ' Joy '
#  ' Positive  ' ' Joy ' ' Excitement ' ' Joy ' ' Joy ' ' Contentment '
#  ' Joy ' ' Excitement ' ' Excitement ' ' Excitement ' ' Excitement '
#  ' Joy ' ' Hopeful ' ' Excitement ' ' Joy ' ' Joy ' ' Excitement '
#  ' Contentment ' ' Joy ' ' Excitement ' ' Positive  ' ' Joy ' ' Joy '
#  ' Excitement ' ' Joy ' ' Joy ' ' Joy ' ' Joy ' ' Excitement ' ' Joy '
#  ' Joy ' ' Joy ' ' Joy ' ' Proud ' ' Sad ' ' Excitement ' ' Joy '
#  ' Excitement ' ' Excitement ' ' Joy ' ' Excitement ' ' Joy '
#  ' Excitement ' ' Excitement ' ' Joy ' ' Excitement ' ' Contentment '
#  ' Excitement ' ' Excitement ' ' Excitement ' ' Joy ' ' Frustrated '
# ...

# %%
print(y_test)
# Out:
# 604           Curiosity
# 33            Positive
# 300             Fearful
# 457          Heartbreak
# 634                 Joy
#              ...
# 70         Calmness
# 192         Jealousy
# 328             Envious
# 165     Loneliness
# 135       Elation
# Name: Sentiment, Length: 147, dtype: object

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.14285714285714285

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                          precision    recall  f1-score   support
#
#          Acceptance          0.00      0.00      0.00         2
#       Acceptance             0.00      0.00      0.00         0
#            Admiration        0.00      0.00      0.00         1
#         Admiration           0.00      0.00      0.00         1
#          Affection           0.00      0.00      0.00         1
#       Ambivalence            0.00      0.00      0.00         1
#          Anger               0.00      0.00      0.00         1
#         Anticipation         0.00      0.00      0.00         1
#         Arousal              0.00      0.00      0.00         3
#                   Awe        0.00      0.00      0.00         1
#          Awe                 0.00      0.00      0.00         1
#                   Bad        0.00      0.00      0.00         1
#              Betrayal        0.00      0.00      0.00         2
# ...

# %%
y_pred_series = pd.Series(y_pred, index=y_test.index)
correlation = y_test.astype('category').cat.codes.corr(y_pred_series.astype('category').cat.codes)

print(f"Correlation between y_test and y_pred: {correlation}")

# Keep the previous prints for completeness
# Out:
# Correlation between y_test and y_pred: 0.2156724148031362

# %%
y_pred_series = pd.Series(y_pred, index=y_test.index)
Covariance = y_test.astype('category').cat.codes.corr(y_pred_series.astype('category').cat.codes)

print(f"Covariance between y_test and y_pred: {Covariance}")
# Out:
# Covariance between y_test and y_pred: 0.2156724148031362

# %%
x_test_series = pd.Series(y_test, index=y_train.index)
# Corrected the variable name from y_test_series to x_test_series
Covariance = y_train.astype('category').cat.codes.corr(x_test_series.astype('category').cat.codes)

print(f"Correlation between x_test and x_train: {correlation}")
# Out:
# Correlation between x_test and x_train: 0.2156724148031362
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
x_test_series = pd.Series(y_test, index=y_train.index)
# Corrected the variable name from y_test_series to x_test_series
Covariance = y_train.astype('category').cat.codes.corr(x_test_series.astype('category').cat.codes)

print(f"Covariance between x_test and x_train: {Covariance}")
# Out:
# Covariance between x_test and x_train: nan
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
sns.barplot(x=df['id'], y=df['Platform'])
plt.title('id vs platform')
plt.xlabel('id')
plt.ylabel('platform')
plt.figure(figsize=(5,8))
plt.show()

# %%
import plotly.express as px
#likes_counts=df['Likes'].value_counts()

selected_Likes = df[df['Likes'].isin(['India', 'USA', 'Canada','Australia'])]
Likes_counts = selected_countries['Likes'].value_counts()

# Use a bar plot to visualize the counts
plt.figure(figsize=(7, 6))
Likes_counts.plot(kind='bar')
plt.title('Likes Distribution in Selected Countries (India, USA, Canada, Australia)')
plt.xlabel('Platform')
plt.ylabel('Likes_counts')
#plt.xticks(rotation=45, ha='right
plt.show()

# %%
import plotly.express as px
selected_countries = df[df['Country'].isin(['India', 'USA', 'Canada','Australia'])]
platform_counts = selected_countries['Platform'].value_counts()
plt.figure(figsize=(7, 6))
platform_counts.plot(kind='bar')
plt.title('Platform Distribution in Selected Countries (India, USA, Canada, Australia)')
plt.xlabel('Platform')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df['Sentiment'].value_counts().nlargest(10).plot(kind='bar')
plt.title('Sentiments based on Text')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
# Assuming you want to see the correlation of numerical columns in the entire DataFrame
sns.heatmap(df.corr(numeric_only=True), color='red', annot=True) # Added numeric_only=True to handle non-numeric columns
plt.show()
